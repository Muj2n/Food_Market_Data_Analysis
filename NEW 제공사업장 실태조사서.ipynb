# %%
import pandas as pd
df = pd.read_csv('NEW 제공사업장 실태조사서.csv', encoding='cp949')

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#           사업장명    운영형태 신고기준  지원센터코드    지원센터(사업장본명) 지정일자(광역)/신고일자(기초)  당연전환  \
# 0     부산광역푸드뱅크  광역지원센터   당연  S02501      부산시광역푸드뱅크        2020-07-01     0
# 1    강서구기초푸드뱅크  기초푸드뱅크   임의  S03701        강서구푸드뱅크        2002-01-01     0
# 2    강서구기초푸드마켓  기초푸드마켓   임의  S64801      강서구둥지푸드마켓        2017-09-27     0
# 3    금정구기초푸드뱅크  기초푸드뱅크   임의  S03601        금정구푸드뱅크        2000-10-01     0
# 4      금정구푸드마켓  기초푸드마켓   임의  S51401      부산금정구푸드마켓        2011-12-30     0
# 5    기장군기초푸드뱅크  기초푸드뱅크   임의  S04101        기장군푸드뱅크        2016-03-15     0
# 6    기장군기초푸드마켓  기초푸드마켓   임의  S63901         기장푸드마켓        2017-04-28     0
# 7     남구기초푸드뱅크  기초푸드뱅크   임의  S03201         남구푸드뱅크        2007-04-25     0
# 8     남구기초푸드마켓  기초푸드마켓   당연  S48201       남구동행푸드마켓        2010-10-01     0
# 9     동구기초푸드뱅크  기초푸드뱅크   임의  S02801         동구푸드뱅크        2002-01-01     0
# 10    동구기초푸드마켓  기초푸드마켓   임의  S64001         동구푸드마켓        2017-05-26     0
# ...
