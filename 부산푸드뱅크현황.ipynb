# %% [markdown]
# # 부산푸드뱅크현황 분석

# %%
import pandas as pd
df = pd.read_csv('부산광역시_푸드뱅크 및 푸드마켓 현황_20230201.csv', encoding='cp949')

# %%
df
# Out:
#       구분   구군명                       운영단체명  대표자  \
# 0   푸드뱅크   연제구      부산광역푸드뱅크(부산광역시사회복지협의회)  오흥숙
# 1   푸드뱅크    중구                   중구종합사회복지관  조혜영
# 2   푸드뱅크    서구                   사회복지법인 팔복  조생래
# 3   푸드뱅크    동구                   동구종합사회복지관  김성용
# 4   푸드뱅크   영도구                   상리종합사회복지관  김영신
# 5   푸드뱅크  부산진구                   당감종합사회복지관  박현애
# 6   푸드뱅크   동래구                   동래종합사회복지관  하소연
# 7   푸드뱅크    남구                   남구종합사회복지관  윤성희
# 8   푸드뱅크    북구                   덕천종합사회복지관  서경복
# 9   푸드뱅크  해운대구                  해운대종합사회복지관  정영희
# 10  푸드뱅크   사하구                   두송종합사회복지관  김태형
# 11  푸드뱅크   금정구                   남광종합사회복지관  박해영
# 12  푸드뱅크   강서구                   낙동종합사회복지관  권기철
# 13  푸드뱅크   연제구                연제구연산종합사회복지관  전현수
# 14  푸드뱅크   수영구                   부산종합사회복지관  구춘희
# 15  푸드뱅크   사상구                   백양종합사회복지관  이혜정
# 16  푸드뱅크   기장군                   대한성공회유지재단  권기철
# 17  푸드마켓    중구     중구 다솜나래푸드마켓 (중구종합사회복지관)  조혜영
# 18  푸드마켓    서구      푸르미&나누미푸드마켓(사회복지법인 팔복)  조생래
# 19  푸드마켓    동구           동구 푸드마켓(작은나눔협동조합)  권지후
# 20  푸드마켓   영도구         영도구 푸드마켓(상리종합사회복지관)  김영신
# 21  푸드마켓  부산진구        부산진구 푸드마켓(당감종합사회복지관)  박현애
# 22  푸드마켓   동래구      동래 등대지기푸드마켓(동래종합사회복지관)  하소연
# 23  푸드마켓    남구           남구 동행푸드마켓(둥지복지마을)  김순희
# 24  푸드마켓    북구        북구 행복푸드마켓(덕천종합사회복지관)  서경복
# 25  푸드마켓  해운대구         해운대푸드마켓(해운대종합사회복지관)  정영희
# 26  푸드마켓   사하구      사하사랑나눔 푸드마켓(두송종합사회복지관)  김태형
# 27  푸드마켓   금정구         금정구 푸드마켓(사회복지법인 선양)  김수현
# 28  푸드마켓   강서구     강서구 둥지푸드마켓(사단법인 둥지복지마을)  김순희
# 29  푸드마켓   연제구     연제구 둥지푸드마켓(사단법인 둥지복지마을)  김순희
# 30  푸드마켓   수영구  함께 하는 푸드마켓(사단법인 국제청소년복지연맹)  구영찬
# 31  푸드마켓   사상구         사상구 푸드마켓(백양종합사회복지관)  정병우
# 32  푸드마켓   기장군      기장푸드마켓(사단법인 국제청소년복지연맹)  김진건
#
#                                 소재지         위도          경도           연락처  \
# 0   부산광역시 연제구 법원남로16번길27, 901호(거제동)  35.191899  129.075184  051-791-1377
# 4   2023-02-01
# 5   2023-02-01
# 6   2023-02-01
# 7   2023-02-01
# 8   2023-02-01
# 9   2023-02-01
# 10  2023-02-01
# 11  2023-02-01
# 12  2023-02-01
# 13  2023-02-01
# 14  2023-02-01
# 15  2023-02-01
# 16  2023-02-01
# 17  2023-02-01
# 18  2023-02-01
# 19  2023-02-01
# 20  2023-02-01
# 21  2023-02-01
# 22  2023-02-01
# 23  2023-02-01
# 24  2023-02-01
# 25  2023-02-01
# 26  2023-02-01
# 27  2023-02-01
# 28  2023-02-01
# 29  2023-02-01
# 30  2023-02-01
# 31  2023-02-01
# 32  2023-02-01

# %%
df[df['구군명'] == '영도구']
# Out:
#       구분  구군명                운영단체명  대표자                       소재지         위도  \
# 4   푸드뱅크  영도구            상리종합사회복지관  김영신  부산광역시 영도구 상리로 63-16(동삼동)  35.086168
# 20  푸드마켓  영도구  영도구 푸드마켓(상리종합사회복지관)  김영신     부산광역시 영도구 태종로514(동삼동)  35.084514
#
#             경도           연락처     데이터기준일자
# 4   129.070776  051-404-5061  2023-02-01
# 20  129.073332  051-405-1377  2023-02-01

# %%
df['구군명'].value_counts()
# Out:
# 연제구     3
# 중구      2
# 서구      2
# 동구      2
# 영도구     2
# 부산진구    2
# 동래구     2
# 남구      2
# 북구      2
# 해운대구    2
# 사하구     2
# 금정구     2
# 강서구     2
# 수영구     2
# 사상구     2
# 기장군     2
# Name: 구군명, dtype: int64

# %% [markdown]
# ## 지도 시각화
# - 푸드뱅크
# - 푸드마켓

# %%
# 라이브러리
import folium
import webbrowser
from folium import IFrame

# 맵 생성
map = folium.Map(location=[df['위도'].mean(), df['경도'].mean()], zoom_start=11)

# 데이터프레임의 각 위치에 마커 추가
for i in df.index:
    name =df.loc[i, '구분']
    gugun = df.loc[i, '구군명']
    location = df.loc[i, '소재지']
    tel = df.loc[i, '연락처']
    
    # 팝업 내용 지정(폰트 설정 등..)
    popup_content = f'<div style="font-family: Arial, sans-serif; font-size: 14px;"> [{gugun} {name}]<br>{location}<br>Tel. {tel}</div>'
    
    # IFrame을 사용하여 수평으로 표시되도록 팝업 설정
    popup = folium.Popup(IFrame(html=popup_content, width=200, height=80))
    
    # 'bank'와 'market'에 대한 아이콘 정의
    bank_icon = folium.CustomIcon(icon_image='bank (2).png', icon_size=(30, 30))
    market_icon = folium.CustomIcon(icon_image='market.png', icon_size=(30, 30))
    
    # 이름에 따라 해당하는 아이콘 선택
    if '뱅크' in name:
        icon = bank_icon
    elif '마켓' in name:
        icon = market_icon
    else:
        icon = None
    
    # 마커 생성 및 팝업 추가
    marker = folium.Marker(
        location=[df.loc[i, '위도'], df.loc[i, '경도']],
        icon=icon,
        popup=popup
    )
    marker.add_to(map)

# 맵을 HTML 파일로 저장
map.save('map.html')

# # 출력 화면에 맵 열기
# map

# 새로운 웹 브라우저에서 맵 열기
webbrowser.open('map.html')
# Out:
# True
